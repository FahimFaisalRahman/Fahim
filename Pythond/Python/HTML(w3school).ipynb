# %% [markdown]
# <h1>Welcome to My Webpage</h1>
# <p>This is a <strong>sample</strong> paragraph styled with HTML.</p>
# <ul>
#     <li>Item 1</li>
#     <li>Item 2</li>
# </ul>
# <img src="https://example.com/image.jpg" alt="Sample Image" width="200">

# %%
from IPython.display import HTML

html_content = """
<div style='background-color: #f0f0f0; padding: 10px;'>
    <h2>Interactive HTML Example</h2>
    <p style='color: blue;'>This paragraph is styled with inline CSS.</p>
    <button onclick='alert("Hello from JavaScript!")'>Click Me</button>
</div>
"""
HTML(html_content)
# Out:
# <div style='background-color: #f0f0f0; padding: 10px;'>
#     <h2>Interactive HTML Example</h2>
#     <p style='color: blue;'>This paragraph is styled with inline CSS.</p>
#     <button onclick='alert("Hello from JavaScript!")'>Click Me</button>
# </div>

# %%
from IPython.display import HTML

items = ["Apple", "Banana", "Orange"]
html_list = "<ul>" + "".join(f"<li>{item}</li>" for item in items) + "</ul>"
HTML(f"<h3>Fruit List</h3>{html_list}")
# Out:
# <h3>Fruit List</h3><ul><li>Apple</li><li>Banana</li><li>Orange</li></ul>

# %%
html_content = """
<!DOCTYPE html>
<html lang='en'>
<head>
    <meta charset='UTF-8'>
    <title>My Webpage</title>
    <style>
        body { font-family: Arial, sans-serif; }
        .container { max-width: 600px; margin: 0 auto; }
    </style>
</head>
<body>
    <div class='container'>
        <h1>My Jupyter HTML Page</h1>
        <p>This page was generated from a Jupyter Notebook.</p>
    </div>
</body>
</html>
"""

with open('output.html', 'w') as file:
    file.write(html_content)

# %%
import webbrowser
webbrowser.open('output.html')
# Out:
# True

# %%
# !pip install ipywidgets

# %%
from IPython.display import HTML
import ipywidgets as widgets
from IPython.display import display

# Create a text input widget
text_input = widgets.Text(description="Name:", value="Enter your name")
output = widgets.HTML(value="")

def on_text_change(change):
    output.value = f"<h3>Hello, {change['new']}!</h3>"

text_input.observe(on_text_change, names='value')
display(text_input, output)
# Out:
# Text(value='Enter your name', description='Name:')
# HTML(value='')

# %%
from IPython.display import IFrame
IFrame(src='output.html', width=700, height=400)
# Out:
#         <iframe
#             width="700"
#             height="400"
#             src="output.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import HTML
from IPython.display import HTML
html_content = """
<!DOCTYPE html>
<html>
<body>

<h1>My First Heading</h1>

<p>My first paragraph.</p>

</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>My First Heading</h1>
#
# <p>My first paragraph.</p>
#
# </body>
# </html>

# %%
from IPython.display import HTML
from IPython.display import HTML
html_content = """
<!DOCTYPE html>
<html>
<body>

<h1>My First Heading</h1>

<p>My first paragraph.</p>

<a href = "https://www.facebook.com">This is a link</a>

</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>My First Heading</h1>
#
# <p>My first paragraph.</p>
#
# <a href = "https://www.facebook.com">This is a link</a>
#
# </body>
# </html>

# %%
from IPython.display import HTML
from IPython.display import HTML
html_content = """
<!DOCTYPE html>
<html lang="en">
<body>

<h1>My First Heading</h1>

<p style="color:red;">My first paragraph.</p>

<a href = "https://www.facebook.com">This is a link</a>
<img src = "girl.jpg" width="500" height="600" alt="Girl with a smile">

</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <body>
#
# <h1>My First Heading</h1>
#
# <p style="color:red;">My first paragraph.</p>
#
# <a href = "https://www.facebook.com">This is a link</a>
# <img src = "girl.jpg" width="500" height="600" alt="Girl with a smile">
#
# </body>
# </html>

# %%
from IPython.display import HTML 
from IPython.display import display

html_content="""
<!DOCTYPE HTML> 
<html>
<body>

<h1 style="font-size:60px;">This is my website</h1>
<h2 style="font-size:10px;">My website design is cool</h1>
<p title = "I'm the king" style="color:red" style="font-size:100px;">This is king's place.</p>
<p>This is a paragraph <br> with line breaks. </p>
<p>The pre tag preserves both spaces and line breaks:
</p>
<pre> 
    My Bonnie lies over the ocean.

    My Bonnie lies over the sea.

    My Bonnie lies over the ocean.
   
    Oh, bring back my Bonnie to me.
</pre>
<a href = "https://www.youtube.com">Youtube</a>

</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
#
# <h1 style="font-size:60px;">This is my website</h1>
# <h2 style="font-size:10px;">My website design is cool</h1>
# <p title = "I'm the king" style="color:red" style="font-size:100px;">This is king's place.</p>
# <p>This is a paragraph <br> with line breaks. </p>
# <p>The pre tag preserves both spaces and line breaks:
# </p>
# <pre>
#     My Bonnie lies over the ocean.
#
#     My Bonnie lies over the sea.
#
#     My Bonnie lies over the ocean.
#
#     Oh, bring back my Bonnie to me.
# </pre>
# <a href = "https://www.youtube.com">Youtube</a>
#
# </body>
# </html>

# %%
from IPython.display import display
html_content="""
<!DOCTYPE HTML>
<html>
<body>
<h1 style="color:blue; font-family:verdana; font-size:300%; text-align:center;">This is a heading</h1>
<p style="color:red; font-family:courier; font-size:160%; text-align:center;">This is a paragraph</p>

</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h1 style="color:blue; font-family:verdana; font-size:300%; text-align:center;">This is a heading</h1>
# <p style="color:red; font-family:courier; font-size:160%; text-align:center;">This is a paragraph</p>
#
# </html>
# </body>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<body> 
<h1 style="color:blue;font-family:verdana; font-size:300%; text-align:center;"><strong>This is a heading</strong></h1>
<p style="color:red; font-family:courier; font-size:160%; text-align:center;"><strong><i>This is a paragraph</strong></i></p>
<p><em>This text is emphasized</em></p>
<p><small>This text is small</small></p>
<p>This word is <mark style="background-color:blue; color:white;">marked</mark>.</p>
<p>My favorite color is <del>black</del> white.</p>
<p>My Favorite colors are:</p>
<li>1. White</li>
    <li>2. Blue</li>
</ul>
</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h1 style="color:blue;font-family:verdana; font-size:300%; text-align:center;"><strong>This is a heading</strong></h1>
# <p style="color:red; font-family:courier; font-size:160%; text-align:center;"><strong><i>This is a paragraph</strong></i></p>
# <p><em>This text is emphasized</em></p>
# <p><small>This text is small</small></p>
# <p>This word is <mark style="background-color:blue; color:white;">marked</mark>.</p>
# <p>My favorite color is <del>black</del> white.</p>
# <p>My Favorite colors are:</p>
# <li>1. White</li>
#     <li>2. Blue</li>
# </ul>
# </html>
# </body>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<body>
<p>This <sub>subscripted</sub>text.</p>
<p>This is <sup>superscripted</sup>text.</p>

</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <p>This <sub>subscripted</sub>text.</p>
# <p>This is <sup>superscripted</sup>text.</p>
#
# </html>
# </body>

# %%
from IPython.display import display 
html_content="""
<html>
<body>
<h1> Wildlife</h1>
<p>This page is about WildLife</p>
<blockquote cite = "http://www.worldwildlife.org/who/index.html">
For 60 years, WWF has worked to help people and nature thrive. As the world's leading conservation
organization, WWF works in nearly 100 countries. At every level, we collaborate with people around the world 
to develop and deliver innovative solutions that protect communities, wildlife, and the places in
which they live.
</blockquote>
<img src = "girl.jpg">
<p>WWF's goal is to: <q>Build a future where people live in harmony in nature.</q></p>
</html>
</body>
"""
HTML(html_content)
# Out:
# <html>
# <body>
# <h1> Wildlife</h1>
# <p>This page is about WildLife</p>
# <blockquote cite = "http://www.worldwildlife.org/who/index.html">
# For 60 years, WWF has worked to help people and nature thrive. As the world's leading conservation
# organization, WWF works in nearly 100 countries. At every level, we collaborate with people around the world
# to develop and deliver innovative solutions that protect communities, wildlife, and the places in
# which they live.
# </blockquote>
# <img src = "girl.jpg">
# <p>WWF's goal is to: <q>Build a future where people live in harmony in nature.</q></p>
# </html>
# </body>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<body> 
<h1>This website is about Wild Life</h1>
<blockquote cite ="http://www.worldwildlife.org/who/index.html">
For 60 years, WWF has worked to help people and nature thrive. As the world's leading conservation
organization, WWF works in nearly 100 countries. At every level, we collaborate with people around the world 
to develop and deliver innovative solutions that protect communities, wildlife, and the places in
which they live.
</blockquote>
<p>The <abbr title="World Health Organization"> WHO </abbr>was founded in 1948.</p>
<address>
Written by Fahim Faisal Rahman.</br>
Visit us at: </br>
Example.com<br>
Unknown Address<br>
BANGLADESH
</address>

</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h1>This website is about Wild Life</h1>
# <blockquote cite ="http://www.worldwildlife.org/who/index.html">
# For 60 years, WWF has worked to help people and nature thrive. As the world's leading conservation
# organization, WWF works in nearly 100 countries. At every level, we collaborate with people around the world
# to develop and deliver innovative solutions that protect communities, wildlife, and the places in
# which they live.
# </blockquote>
# <p>The <abbr title="World Health Organization"> WHO </abbr>was founded in 1948.</p>
# <address>
# Written by Fahim Faisal Rahman.</br>
# Visit us at: </br>
# Example.com<br>
# Unknown Address<br>
# BANGLADESH
# </address>
#
# </html>
# </body>

# %%
from IPython.display import display 
html_content = """
<!DOCTYPE HTML>
<html>
<body> 
<p> The HMTL cite element defines the title of a work.</p>
<p> Browsers usually display cite elements in italic.</p>

<img src = "img_the_scream.jpg" width="220"
height="277" alt="The Scream">
<p><cite>The Scream</cite> by Edward Munch. Painted in 1893,</p>
</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <p> The HMTL cite element defines the title of a work.</p>
# <p> Browsers usually display cite elements in italic.</p>
#
# <img src = "img_the_scream.jpg" width="220"
# height="277" alt="The Scream">
# <p><cite>The Scream</cite> by Edward Munch. Painted in 1893,</p>
# </html>
# </body>

# %%
from IPython.display import display 
html_content = """
<!DOCTYPE HTML>
<html>
<body>
<!--This is a comment -->
<!--<p>This is another paragraph </p> -->

<p>If your browser supports bi-directional override (bdo), the next line will be written from right to left(rtl):</p>
<bdo dir="rtl">This line will be written from right to left</bdo>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <!--This is a comment -->
# <!--<p>This is another paragraph </p> -->
#
# <p>If your browser supports bi-directional override (bdo), the next line will be written from right to left(rtl):</p>
# <bdo dir="rtl">This line will be written from right to left</bdo>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<body>
<h1 style="border:2px solid Tomato;">Hello world</h1>
<h1 style="border:2px solid DodgerBlue;">Hello world</h1>
<h1 style="border:2px solid Violet;">Hello World</h1>
</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h1 style="border:2px solid Tomato;">Hello world</h1>
# <h1 style="border:2px solid DodgerBlue;">Hello world</h1>
# <h1 style="border:2px solid Violet;">Hello World</h1>
# </html>
# </body>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<body>
<h1 style="background-color:rgb(255, 99, 71);">...</h1>
<h1 style="background-color:#ff6347;">...</h1>
<h1 style="background-color:hsl(9, 100%, 64%, 0.5);">...</h1>

<h1 style="background-color:rgba(255, 99, 71, 0.5);">...</h1>
<h1 style="background-color:hsla(9, 100%, 64%, 0.5);">...</h1>

</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h1 style="background-color:rgb(255, 99, 71);">...</h1>
# <h1 style="background-color:#ff6347;">...</h1>
# <h1 style="background-color:hsl(9, 100%, 64%, 0.5);">...</h1>
#
# <h1 style="background-color:rgba(255, 99, 71, 0.5);">...</h1>
# <h1 style="background-color:hsla(9, 100%, 64%, 0.5);">...</h1>
#
# </html>
# </body>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE html>
<html>
<head>
<style>
body {background-color: powderblue;}
h1   {color: blue;}
p    {color: red;}
</style>
</head>
<body>

<h1>This is a heading</h1>
<p>This is a paragraph.</p>

</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# body {background-color: powderblue;}
# h1   {color: blue;}
# p    {color: red;}
# </style>
# </head>
# <body>
#
# <h1>This is a heading</h1>
# <p>This is a paragraph.</p>
#
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<head>
    <link rel ="stylesheet" href="styles.css">
</head>
<h1>This is a heading</h1>
<p>This is a paragraph</p>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
#     <link rel ="stylesheet" href="styles.css">
# </head>
# <h1>This is a heading</h1>
# <p>This is a paragraph</p>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<head>
<style>
h1 {
    color: blue;
    font-family: verdana;
    font-size: 300%
    }
p {
    color: red;
    font-family: courier;
    font-size: 160%
    border: 2px solid powderblue;
    padding: 30px
    margin: 50px
}

</style>
</head>
<body>
<h1>This is a heading</h1>
<p>This is a paragraph</p>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <style>
# h1 {
#     color: blue;
#     font-family: verdana;
#     font-size: 300%
#     }
# p {
#     color: red;
#     font-family: courier;
#     font-size: 160%
#     border: 2px solid powderblue;
#     padding: 30px
#     margin: 50px
# }
#
# </style>
# </head>
# <body>
# <h1>This is a heading</h1>
# <p>This is a paragraph</p>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<head>
<style>
p {
 border: 2px solid powderblue;
 ]

</style>
</head>
<body>
<h1>This is a heading</h1>
<p>This is a paragraph</p>
<p>This is a paragraph</p>
<p>THis is a paragraph</p>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <style>
# p {
#  border: 2px solid powderblue;
#  ]
#
# </style>
# </head>
# <body>
# <h1>This is a heading</h1>
# <p>This is a paragraph</p>
# <p>This is a paragraph</p>
# <p>THis is a paragraph</p>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<head>
<link rel ="stylesheet" href="https://www.w3schools.com/html/styles.css">
</head>
<h1>This is a heading</h1>
<p>This is a paragraph</p>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <link rel ="stylesheet" href="https://www.w3schools.com/html/styles.css">
# </head>
# <h1>This is a heading</h1>
# <p>This is a paragraph</p>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<body>
<h2>The target attribute</h2>
<a href="https://www.youtube.com/" target="_blank">Visit Youtube!</a>

<p1>If target="_blank", the link will open in a new browser window or tab.</p1>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h2>The target attribute</h2>
# <a href="https://www.youtube.com/" target="_blank">Visit Youtube!</a>
#
# <p1>If target="_blank", the link will open in a new browser window or tab.</p1>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE html>
<html>
<body>

<h2>Absolute URLs</h2>
<p1><a href="https://www.w3.org/" target="_blank">W3C</a></p1>
<p1><a href="https://www.google.com/" target="_blank">Google</a></p1>

<h2>Relative URLs</h2>
<p1><a href="html_images.asp">HTML Images</a></p1>
<p1><a href="/css/default.asp">CSS Tutorial</a></p1>

</body>
</html>

"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Absolute URLs</h2>
# <p1><a href="https://www.w3.org/" target="_blank">W3C</a></p1>
# <p1><a href="https://www.google.com/" target="_blank">Google</a></p1>
#
# <h2>Relative URLs</h2>
# <p1><a href="html_images.asp">HTML Images</a></p1>
# <p1><a href="/css/default.asp">CSS Tutorial</a></p1>
#
# </body>
# </html>

# %%
from IPython.display import display 
html_content = """
<!DOCTYPE HTML>
<html>
<body>
<h1>This is a heading</h1>
<a href="mailto:faisalfahim072@gmail.com">Send email</a>
</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h1>This is a heading</h1>
# <a href="mailto:faisalfahim072@gmail.com">Send email</a>
# </html>
# </body>

# %%
from IPython.display import display 
html_content = """
<!DOCTYPE HTML>
<html>
<body>
<h1>This is a heading</h1>
<button onclick="https://www.youtube.com/">Youtube</button>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h1>This is a heading</h1>
# <button onclick="https://www.youtube.com/">Youtube</button>
# </body>
# </html>

# %% [markdown]
# ***Use an Image as a Link***

# %%
from IPython.display import HTML
from IPython.display import display 

html_content="""
<!DOCTYPE HTML>
<html>
<body>
<h1>Use an Image as an Link</h1>
<a href = "https://www.youtube.com/">
<img src = "girl.jpg" alt="Girl with a smile" style="width:42px;height:42px;">
</a>
</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h1>Use an Image as an Link</h1>
# <a href = "https://www.youtube.com/">
# <img src = "girl.jpg" alt="Girl with a smile" style="width:42px;height:42px;">
# </a>
# </html>
# </body>

# %%
from IPython.display import HTML
from IPython.display import display 

html_content="""
<!DOCTYPE HTML>
<html>
<body>
<h1>Link Titles</h1>
<a href = "https://www.youtube.com/" title="Go to Youtube">Visit our Youtube Page</a>
</html>
</body>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h1>Link Titles</h1>
# <a href = "https://www.youtube.com/" title="Go to Youtube">Visit our Youtube Page</a>
# </html>
# </body>

# %%
from IPython.display import HTML
from IPython.display import display 

html_content = """
<!DOCTYPE html>
<html>
<head>
<style>
/* Use a more specific selector or !important to override default styles */
a {
  color: green !important; /* Force green color for all link states */
  background-color: transparent;
  text-decoration: none;
}
a:visited {
  color: pink;
  background-color: transparent;
  text-decoration: none;
}
a:hover {
  color: red;
  background-color: transparent;
  text-decoration: underline;
}
a:active {
  color: yellow;
  background-color: transparent;
  text-decoration: underline;
}
</style>
</head>
<body>

<h2>Link Colors</h2>

<p>You can change the default colors of links</p>

<a href="https://www.youtube.com/" target="_blank">HTML Images</a> 

</body>
</html>
"""
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# /* Use a more specific selector or !important to override default styles */
# a {
#   color: green !important; /* Force green color for all link states */
#   background-color: transparent;
#   text-decoration: none;
# }
# a:visited {
#   color: pink;
#   background-color: transparent;
#   text-decoration: none;
# }
# a:hover {
#   color: red;
#   background-color: transparent;
#   text-decoration: underline;
# }
# a:active {
#   color: yellow;
#   background-color: transparent;
#   text-decoration: underline;
# }
# </style>
# </head>
# <body>
#
# <h2>Link Colors</h2>
#
# <p>You can change the default colors of links</p>
#
# <a href="https://www.youtube.com/" target="_blank">HTML Images</a>
#
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<head>
<style>
a, a:visited {
    background-color: #f44336;
    color: white;
    padding: 15px, 25px
    text-align: center;
    text-decoration: none; 
    display: inline-block;
    }

a:hover, a:active {
    background-color:red;
    }
</style>
</head>
<body>
<h2>Link Button</h2>
<p> A link styled as a button:</p>
<a href="https://www.youtube.com/" target="_blank">This is a link</a>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <style>
# a, a:visited {
#     background-color: #f44336;
#     color: white;
#     padding: 15px, 25px
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     }
#
# a:hover, a:active {
#     background-color:red;
#     }
# </style>
# </head>
# <body>
# <h2>Link Button</h2>
# <p> A link styled as a button:</p>
# <a href="https://www.youtube.com/" target="_blank">This is a link</a>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<h2>Images on Another Server</h2>
<img src="https://techlandbd.com/cache/images/uploads/products/P0082510003/cover-1760002151_cache_optimize-70.webp">
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <h2>Images on Another Server</h2>
# <img src="https://techlandbd.com/cache/images/uploads/products/P0082510003/cover-1760002151_cache_optimize-70.webp">
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<h2>Images on Another Server</h2>
<img src="https://media.tenor.com/GfSX-u7VGM4AAAAM/coding.gif">
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <h2>Images on Another Server</h2>
# <img src="https://media.tenor.com/GfSX-u7VGM4AAAAM/coding.gif">
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<h2>Images on Another Server</h2>
<a href="https://www.youtube.com/">
<img src="https://media.tenor.com/GfSX-u7VGM4AAAAM/coding.gif"></a>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <h2>Images on Another Server</h2>
# <a href="https://www.youtube.com/">
# <img src="https://media.tenor.com/GfSX-u7VGM4AAAAM/coding.gif"></a>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<h2>Images on Another Server</h2>
<a href="https://www.youtube.com/">
<img src="https://media.tenor.com/GfSX-u7VGM4AAAAM/coding.gif"></a>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <h2>Images on Another Server</h2>
# <a href="https://www.youtube.com/">
# <img src="https://media.tenor.com/GfSX-u7VGM4AAAAM/coding.gif"></a>
# </body>
# </html>

# %%
from IPython.display import HTML
from IPython.display import display 
html_content="""
<!DOCTYPE html>
<html>
<body>

<h2>Image Maps</h2>
<p>Click on the computer, the phone, or the cup of coffee to go to a new page and read more about the topic:</p>

<img src="workplace.jpg" alt="Workplace" usemap="#workmap" width="400" height="379">

<map name="workmap">
  <area shape="rect" coords="34,44,270,350" alt="Computer" href="https://en.wikipedia.org/wiki/Computer#:~:text=A%20computer%20is%20a%20machine,a%20wide%20range%20of%20tasks.">
  <area shape="rect" coords="290,172,333,250" alt="Phone" href="https://en.wikipedia.org/wiki/Telephone">
  <area shape="circle" coords="337,300,44" alt="Cup of coffee" href="https://en.wikipedia.org/wiki/Coffee">
</map>

</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>Image Maps</h2>
# <p>Click on the computer, the phone, or the cup of coffee to go to a new page and read more about the topic:</p>
#
# <img src="workplace.jpg" alt="Workplace" usemap="#workmap" width="400" height="379">
#
# <map name="workmap">
#   <area shape="rect" coords="34,44,270,350" alt="Computer" href="https://en.wikipedia.org/wiki/Computer#:~:text=A%20computer%20is%20a%20machine,a%20wide%20range%20of%20tasks.">
#   <area shape="rect" coords="290,172,333,250" alt="Phone" href="https://en.wikipedia.org/wiki/Telephone">
#   <area shape="circle" coords="337,300,44" alt="Cup of coffee" href="https://en.wikipedia.org/wiki/Coffee">
# </map>
#
# </body>
# </html>

# %%
from IPython.display import display 
html_content ="""
<!DOCTYPE HTML>
<html>
<head>
<style>
table {
    font-family: aerial, sans-serif;
    border-collapse: collapse; 
    width: 100;
    }

td, th {
    border: 1px solid #dddddd;
    text-align:left;
    padding: 8px;
    }

tr:nth-child(even) {
    background-color:#dddddd;
}

</style>
</head>
<body>

<h2> HTML Table </h2>

<table> 

<tr>
<th> Company</th>
<th>Contact</th>
<th>Country</th>
</tr>

<tr>
<td>Alfreds Futterkiste</td>
<td>Maria Anders </td>
<td>Germany</td>
</tr>

<tr>
<td>Centro commercial Moctezuma</td>
<td>Franciso Chang</td>
<td>Mexico</td>
</tr>

<tr>
<td>Ernst Handel</td>
<td>Roland Mendel</td>
<td>Austria</td>
</tr> 

<tr>
<td>Island Trading</td>
<td>Helen Bennet</td>
<td>UK</td>
</tr>

<tr>
<td>Laughing Bacchus Winecellars</td>
<td>Yoshi Tannamuri</td>
<td>Canada</td>
</tr>

<tr>
<td>Magazzini Alimentari Riuniti</td>
<td>Giovanni Rovelli</td>
<td>Italy</td>
</tr>
</table>

</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <style>
# table {
#     font-family: aerial, sans-serif;
#     border-collapse: collapse;
#     width: 100;
#     }
#
# td, th {
#     border: 1px solid #dddddd;
#     text-align:left;
#     padding: 8px;
#     }
#
# tr:nth-child(even) {
#     background-color:#dddddd;
# }
#
# </style>
# </head>
# <body>
#
# <h2> HTML Table </h2>
#
# <table>
#
# <tr>
# <th> Company</th>
# <th>Contact</th>
# <th>Country</th>
# </tr>
#
# <tr>
# <td>Alfreds Futterkiste</td>
# <td>Maria Anders </td>
# <td>Germany</td>
# </tr>
#
# <tr>
# <td>Centro commercial Moctezuma</td>
# <td>Franciso Chang</td>
# <td>Mexico</td>
# </tr>
#
# <tr>
# <td>Ernst Handel</td>
# <td>Roland Mendel</td>
# <td>Austria</td>
# </tr>
#
# <tr>
# <td>Island Trading</td>
# <td>Helen Bennet</td>
# <td>UK</td>
# </tr>
#
# <tr>
# <td>Laughing Bacchus Winecellars</td>
# <td>Yoshi Tannamuri</td>
# <td>Canada</td>
# </tr>
#
# <tr>
# <td>Magazzini Alimentari Riuniti</td>
# <td>Giovanni Rovelli</td>
# ...

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE html>
<html>
<body>

<h2>An Unordered HTML List</h2>

<ul>
  <li>Coffee</li>
  <li>Tea</li>
  <li>Milk</li>
</ul>  

<h2>An Ordered HTML List</h2>

<ol>
  <li>Coffee</li>
  <li>Tea</li>
  <li>Milk</li>
</ol> 

</body>
</html>

"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>An Unordered HTML List</h2>
#
# <ul>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ul>
#
# <h2>An Ordered HTML List</h2>
#
# <ol>
#   <li>Coffee</li>
#   <li>Tea</li>
#   <li>Milk</li>
# </ol>
#
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""

<!DOCTYPE html>
<html>
<body>

<h2>A Description List</h2>

<dl>
  <dt>Coffee</dt>
  <dd>- black hot drink</dd>
  <dt>Milk</dt>
  <dd>- white cold drink</dd>
</dl>

</body>
</html>


"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h2>A Description List</h2>
#
# <dl>
#   <dt>Coffee</dt>
#   <dd>- black hot drink</dd>
#   <dt>Milk</dt>
#   <dd>- white cold drink</dd>
# </dl>
#
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<div style="background-color:black;color:white;padding:20px;">
<h2>London</h2>
<p1>London is the capital city of England. It is the most populous city in the 
United Kingdom, with a metropolitan area of over 13 million inhabitants.</p1>
<p1>Standing on the River Thames, London has been a major settlement for two 
millenia, its history going back to its founding by the Romans, who named it 
Londinium.</p1>
</div>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <div style="background-color:black;color:white;padding:20px;">
# <h2>London</h2>
# <p1>London is the capital city of England. It is the most populous city in the
# United Kingdom, with a metropolitan area of over 13 million inhabitants.</p1>
# <p1>Standing on the River Thames, London has been a major settlement for two
# millenia, its history going back to its founding by the Romans, who named it
# Londinium.</p1>
# </div>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<head>
<style>
.city {
    background-color: tomato;
    color: white;
    border: 2px solid black;
    margin: 20px;
    padding: 20px;
    }
</style>
</head>
<body>

<div class="city">
<h2>London</h2>
<p1>London is the capital of England</p1>
</div>

<div class = "city">
<h2>Paris</h2>
<p1>Paris is the capital of France</p1>
</div>

<div class = "city">
<h2>Tokyo</h2>
<p1>Tokyo is the capital of Japan</p1>
</div>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <style>
# .city {
#     background-color: tomato;
#     color: white;
#     border: 2px solid black;
#     margin: 20px;
#     padding: 20px;
#     }
# </style>
# </head>
# <body>
#
# <div class="city">
# <h2>London</h2>
# <p1>London is the capital of England</p1>
# </div>
#
# <div class = "city">
# <h2>Paris</h2>
# <p1>Paris is the capital of France</p1>
# </div>
#
# <div class = "city">
# <h2>Tokyo</h2>
# <p1>Tokyo is the capital of Japan</p1>
# </div>
# </body>
# </html>

# %%
from IPython.display import HTML
from IPython.display import display 

html_content="""
<!DOCTYPE HTML>
<html>
<body>
<p1>This is an inline frame which is used to embed another document within the current HTML document.</p1>
<iframe src="https://www.wikipedia.org/" height="500", width="700"></iframe>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <p1>This is an inline frame which is used to embed another document within the current HTML document.</p1>
# <iframe src="https://www.wikipedia.org/" height="500", width="700"></iframe>
# </body>
# </html>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE html>
<html>
<body>

<h1>My First JavaScript</h1>

<button type="button"
onclick="document.getElementById('demo').innerHTML = Date()">
Click me to display Date and Time.</button>

<p1 id="demo"></p1>

</body>
</html> 
"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>My First JavaScript</h1>
#
# <button type="button"
# onclick="document.getElementById('demo').innerHTML = Date()">
# Click me to display Date and Time.</button>
#
# <p1 id="demo"></p1>
#
# </body>
# </html>

# %%
from IPython.display import HTML

html_content = """
<div id="interactive-demo">
    <h1>My First JavaScript</h1>
    <p1>JavaScript can change the content of an HTML element:</p1>
    <button onclick="document.getElementById('demo-text').innerHTML='Hello JavaScript!'">Click Me!</button>
    <p1 id="demo-text">This is a demonstration.</p1>
</div>
"""

display(HTML(html_content))
# Out:
# <div id="interactive-demo">
#     <h1>My First JavaScript</h1>
#     <p1>JavaScript can change the content of an HTML element:</p1>
#     <button onclick="document.getElementById('demo-text').innerHTML='Hello JavaScript!'">Click Me!</button>
#     <p1 id="demo-text">This is a demonstration.</p1>
# </div>

# %%
from IPython.display import display 
html_content="""
<!DOCTYPE HTML>
<html>
<body>
<h2>HTML Forms</h2>
<form action="/action_page.php">
<label for ="fname">First Name:</label><br>
<input type="text" id="fname" name="fanme" value="John"><br>
<label for="lname">Last Name:</label><br>
<input type="text" id="lname" name="lname"
value="Doe"><br><br>
<input type="submit" value="Submit"></form>

<p1>If you click the "Submit, the form-data will be sent to a page called "/action_page.php".</p>

</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
# <h2>HTML Forms</h2>
# <form action="/action_page.php">
# <label for ="fname">First Name:</label><br>
# <input type="text" id="fname" name="fanme" value="John"><br>
# <label for="lname">Last Name:</label><br>
# <input type="text" id="lname" name="lname"
# value="Doe"><br><br>
# <input type="submit" value="Submit"></form>
#
# <p1>If you click the "Submit, the form-data will be sent to a page called "/action_page.php".</p>
#
# </body>
# </html>

# %%
from IPython.display import display
html_content="""
<!DOCTYPE HTML>
<html>
<body>

<video width = "320" height="240" controls>
    <source src = "movie.mp4" type="video/mp4">
    <source src = "movie.ogg" type="video/ogg">
    Your browser does not support the video tag. 
    </video>
</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE HTML>
# <html>
# <body>
#
# <video width = "320" height="240" controls>
#     <source src = "movie.mp4" type="video/mp4">
#     <source src = "movie.ogg" type="video/ogg">
#     Your browser does not support the video tag.
#     </video>
# </body>
# </html>

# %%
from IPython.display import display
html_content="""
<!DOCTYPE html>
<html>
<body>

<iframe width="420" height="345" src="https://www.youtube.com/embed/Hk2XH8EDapc?autoplay=1&mute=1">
</iframe>

</body>
</html>
"""
HTML(html_content)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <iframe width="420" height="345" src="https://www.youtube.com/embed/Hk2XH8EDapc?autoplay=1&mute=1">
# </iframe>
#
# </body>
# </html>
