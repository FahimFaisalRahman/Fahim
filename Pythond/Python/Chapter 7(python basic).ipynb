# %% [markdown]
# # User Input and While Loops

# %% [markdown]
# **How the input() Function Works**

# %%
message = input("Tell me something, and I will repeat it back to you: ")
print(message)
# Out:
# Tell me something, and I will repeat it back to you:  Hello, everyone!
# Hello, everyone!

# %% [markdown]
# **Writing Clear Prompts**

# %%
name = input("Please enter your name: ")
print(f"\nHello, {name}!")
# Out:
# Please enter your name:  Fahim
# Hello, Fahim!

# %%
prompt = "If you tell your name, we can personalize the message you see."
prompt += "\nWhat is your first name? "

name = input(prompt)
print(f"\nHello, {name}!")
# Out:
# If you tell your name, we can personalize the message you see.
# What is your first name?  Fahim
# Hello, Fahim!

# %% [markdown]
# **Using int() to Accept Numerical input**

# %%
age = input("How old are you?")
# Out:
# How old are you? 200

# %%
age
# Out:
# '200'

# %%
age > 300
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 age > 300
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
age = int(age)
age >=300
# Out:
# False

# %%
height = input("How old are you, in inches? ")
height = int(height)

if height >=48:
    print("\nYou're tall enough to ride!")
else:
    print("\nYou'll be able to ride when you're a little older.")
# Out:
# How old are you, in inches?  50
# You're tall enough to ride!

# %%
number = input("Enter a number, I'll tell you whether it's even or odd: ")
number = int(number)

if number %2 == 0:
    print(f"\nThe number {number} is even.")
else:
    print(f"\nThe number {number} is odd.")
# Out:
# Enter a number, I'll tell you whether it's even or odd:  11024
# The number 11024 is even.

# %% [markdown]
# **Exercise**

# %%
# 7-1 Rental Car 
rental_car = input("What kind of car would you like: ")
print(f"Let me see if I can find you a {rental_car.title()}.")
# Out:
# What kind of car would you like:  Toyota
# Let me see if I can find you a Toyota.

# %%
#7-2 Restaurant Seating 

Restaurant_seating = int(input("How many people are in your dinner group: "))

if Restaurant_seating >8:
    print("You'll have to wait for a table")
else: 
    print("Your table is ready.")
# Out:
# How many people are in your dinner group:  7
# Your table is ready.

# %%
#7-3 Multiple of Ten
number = int(input("Enter a number, I'll tell you whether its a multiple of 10 or not."))

if number %10 ==0:
    print(f"\nThe number {number} is multiple of 10.")
else:
    print(f"\nThe number {number} is not multiple of 10.")
# Out:
# Enter a number, I'll tell you whether its a multiple of 10 or not. 10
# The number 10 is multiple of 10.

# %% [markdown]
# ## Introducing while Loops

# %% [markdown]
# **The while Loop in Action**

# %%
current_number = 1
while current_number <=5:
    print(current_number)
    current_number +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Letting the User Choose When to Quit**

# %%
prompt = "\nTell me something, and I will repeat it back to you: "
prompt += "\Enter 'quit' to end the program. "

message = "" 
while message != 'quit':
    message = input(prompt)
    print(message)
# Out:
# Tell me something, and I will repeat it back to you: \Enter 'quit' to end the program.  Hello, everyone
# Hello, everyone
# Tell me something, and I will repeat it back to you: \Enter 'quit' to end the program.  quit
# quit

# %%
prompt = "\nTell me something, and I will repeat it back to you: "
prompt += "\Enter 'quit' to end the program. "

active = True
while active:
    message = input(prompt)

    if message == 'quit':
        active = False
    else:
        print(message)
# Out:
# Tell me something, and I will repeat it back to you: \Enter 'quit' to end the program.  Fahim
# Fahim
# Tell me something, and I will repeat it back to you: \Enter 'quit' to end the program.  quit

# %%
prompt = "\nPlease enter the name of a city you have visited:"
prompt += "\n(Enter 'quit' when you are finished.)"

while True:
    city = input(prompt)

    if city == 'quit':
        break
    else:
        print(f"I'd love to go to {city.title()}!")
# Out:
# Please enter the name of a city you have visited:
# (Enter 'quit' when you are finished.) dhaka
# I'd love to go to Dhaka!
# Please enter the name of a city you have visited:
# (Enter 'quit' when you are finished.) quit

# %% [markdown]
# ## Using Continue in a Loop

# %%
current_number = 0 
while current_number <10:
    current_number += 1
    if current_number % 2 == 0:
        continue
    print(current_number)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# **Avoiding infinite Loops**

# %%
x = 1
while x<=5:
    print(x)
    x +=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Exercise**

# %%
#7-4 Pizza Toppings: 
prompt = "\nPlease enter Pizza toppings: "
prompt += "\n(Enter 'quit' when you are finished.)"

while True:
    Pizza = input(prompt)

    if Pizza == 'quit':
        break
    else:
        print(f"I'm adding {Pizza.title()} toppings to your pizza !")
# Out:
# Please enter Pizza toppings:
# (Enter 'quit' when you are finished.) pineapple
# I'm adding Pineapple toppings to your pizza !
# Please enter Pizza toppings:
# (Enter 'quit' when you are finished.) cheese
# I'm adding Cheese toppings to your pizza !
# Please enter Pizza toppings:
# (Enter 'quit' when you are finished.) quit

# %%
age = int(input("Please enter your age: "))
while age >= 0:
    if age < 3:
        print("Your ticket is free.")
    elif 3 <= age <= 12:
        print("Your ticket costs $10.")
    else:
        print("Your ticket costs $15.")
    age = int(input("Please enter your age (enter a negative number to exit): "))
# Out:
# Please enter your age:  10
# Your ticket costs $10.
# Please enter your age (enter a negative number to exit):  -10

# %% [markdown]
# ## Using a while Loop with Lists and Dictionaires

# %% [markdown]
# **Moving Items from One List to Another**

# %%
# Start with users that need to be verified and emtpy list to hold confirmed users.

unconfirmed_users = ['alice', 'brian', 'candance']
confirmed_users = []

# Verify each user until there are no more unconfirmed users. 
# Move each verified user into the list of confirmed users. 

while unconfirmed_users:
    current_user = unconfirmed_users.pop()
    

    print(f"Verifying user: {current_user.title()}")
    confirmed_users.append(current_user)


# Display all confirmed users. 
print("\nThe following users have been confirmed:")
for confirmed_user in confirmed_users:
    print(confirmed_user.title())
# Out:
# Verifying user: Candance
# Verifying user: Brian
# Verifying user: Alice
#
# The following users have been confirmed:
# Candance
# Brian
# Alice

# %% [markdown]
# **Removing All Instance of Specific Values from a list**

# %%
pets = ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
print(pets)

while 'cat' in pets:
    pets.remove('cat')

print(pets)
# Out:
# ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
# ['dog', 'dog', 'goldfish', 'rabbit']

# %% [markdown]
# **Filling a Dictionary with User Input**

# %%
responses = {}

# Set a flag to indicate that polling is active. 
polling_active = True 

while polling_active:
    #Prompt for the person's name and response. 
    name = input("\nWhat is your name? ")
    response = input("Which mountain would you like to climb someday? ")

    #Store the response in the dictionary. 
    responses[name] = response 

    #Find out if anyone else is going to take the poll. 
    repeat = input("Would you like to let another person respond? (yes/no) ")
    if repeat == 'no':
        polling_active = False

    #Polling is complete. Show the results. 
    print("\n--- Poll Results ---")
    for name, response in responses.items():
        print(f"{name} would you like to climb {response}.")
# Out:
# What is your name?  Fahim
# Which mountain would you like to climb someday?  Himalaya
# Would you like to let another person respond? (yes/no)  yes
# --- Poll Results ---
# Fahim would you like to climb Himalaya.
# What is your name?  Faisal
# Which mountain would you like to climb someday?  Alps
# Would you like to let another person respond? (yes/no)  no
# --- Poll Results ---
# Fahim would you like to climb Himalaya.
# Faisal would you like to climb Alps.

# %% [markdown]
# **Exercise**

# %%
#7-8 Deli

# Start with users that need to be verified and emtpy list to hold sandwich orders

sandwich_orders = ['chicken', 'cheese', 'pineapple']
finished_sandwiches = []

# Verify each user until there are no more unconfirmed users. 
# Move each verified user into the list of confirmed users. 

while sandwich_orders:
    current_sandwich = sandwich_orders.pop()
    

    print(f"Verify_orders: {current_sandwich.title()}")
    finished_sandwiches.append(current_sandwich)


# Display all confirmed users. 
print("\nThe following sandwiches have been made:")
for finished_sandwich in finished_sandwiches:
    print(finished_sandwich.title())
# Out:
# Verify_orders: Pineapple
# Verify_orders: Cheese
# Verify_orders: Chicken
#
# The following sandwiches have been made:
# Pineapple
# Cheese
# Chicken

# %%
# 7-8 No Pastrami 

sandwich_orders = ['chicken', 'pastrami', 'cheese', 'pineapple','pastrami', 'pastrami']

finished_sandwiches = []

# Verify each user until there are no more unconfirmed users. 
# Move each verified user into the list of confirmed users.

while 'pastrami' in sandwich_orders:
    sandwich_orders.remove('pastrami')
print("We have run out pastrami.")

while sandwich_orders:
    current_sandwich = sandwich_orders.pop()
    

    print(f"Verify_orders: {current_sandwich.title()}")
    finished_sandwiches.append(current_sandwich)


# Display all confirmed users. 
print("\nThe following sandwiches have been made:")
for finished_sandwich in finished_sandwiches:
    print(finished_sandwich.title())
# Out:
# We have run out pastrami.
# Verify_orders: Pineapple
# Verify_orders: Cheese
# Verify_orders: Chicken
#
# The following sandwiches have been made:
# Pineapple
# Cheese
# Chicken

# %%
# 7-10 Dream Vacation: 

responses = {}

# Set a flag to indicate that polling is active. 
polling_active = True 

while polling_active:
    #Prompt for the person's name and response. 
    name = input("\nTell me about your Dream Vacation? ")
    response = input("If you would like to visit one place in the world, where would you go? ")

    #Store the response in the dictionary. 
    responses[name] = response 

    #Find out if anyone else is going to take the poll. 
    repeat = input("Would you like to let another person respond? (yes/no) ")
    if repeat == 'no':
        polling_active = False

    #Polling is complete. Show the results. 
    print("\n--- Poll Results ---")
    for name, response in responses.items():
        print(f"{response}.")
# Out:
# Tell me about your Dream Vacation?  World Tour
# If you would like to visit one place in the world, where would you go?  China, USA, Argentina
# Would you like to let another person respond? (yes/no)  yes
# --- Poll Results ---
# China, USA, Argentina.
# Tell me about your Dream Vacation?  World Tour
# If you would like to visit one place in the world, where would you go?  Bangladesh, Somalia, Kenya
# Would you like to let another person respond? (yes/no)  no
# --- Poll Results ---
# China, USA, Argentina.
# Bangladesh, Somalia, Kenya.
