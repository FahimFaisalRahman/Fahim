# %% [markdown]
# # Functions

# %% [markdown]
# **Defining a Function**

# %%
def greet_user():
    """Display a simple greeting."""
    print("Hello!")

greet_user()
# Out:
# Hello!

# %% [markdown]
# ***Passing Information to a Function***

# %%
def greet_user(username):
    print(f"Hello, {username.title()}!")

greet_user('jesse')
# Out:
# Hello, Jesse!

# %% [markdown]
# # Exercise

# %%
#8-1 Message

def display_message():
    print("I am learning functions in this chapter.")

display_message()
# Out:
# I am learning functions in this chapter.

# %%
def favorite_book(title):
    print(f"One of my favorite books is {title.title()}.")

favorite_book('Alice in Wonderland')
# Out:
# One of my favorite books is Alice In Wonderland.

# %% [markdown]
# ## Passing Arguments

# %% [markdown]
# **Positional Arguments**

# %%
def describe_pet(animal_type, pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet('hamster', 'harry')
# Out:
# I have a hamster.
# My hamster's name is Harry.

# %% [markdown]
# **Multiple Function Calls**

# %%
def describe_pet(animal_type, pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet('hamster', 'harry')
describe_pet('dog', 'willie')
# Out:
# I have a hamster.
# My hamster's name is Harry.
#
# I have a dog.
# My dog's name is Willie.

# %% [markdown]
# **Keyword Arguments**

# %%
def describe_pet(animal_type, pet_name):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet(pet_name='harry', animal_type='hamster')
# Out:
# I have a hamster.
# My hamster's name is Harry.

# %% [markdown]
# **Default Values**

# %%
def describe_pet(pet_name, animal_type='dog'):
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet(pet_name='Willie')
# Out:
# I have a dog.
# My dog's name is Willie.

# %% [markdown]
# **Exercise**

# %%
#8-3 (a) T-Shirt
def make_shirt(size, text_message):
    print(f"This T-shirt is {size} size and {text_message.title()} is written on the T-Shirt.")

make_shirt('medium', 'I love Python')
# Out:
# This T-shirt is medium size and I Love Python is written on the T-Shirt.

# %%
#8-3 (b) T-Shirt

def make_shirt(size, text_message):
     print(f"This T-shirt is {size} size and {text_message.title()} is written on the T-Shirt.")
make_shirt('medium', text_message='I love Python')
# Out:
# This T-shirt is medium size and I Love Python is written on the T-Shirt.

# %%
#8-4 Large Shirts
def make_shirt(size="large", message="I love Python"):
    """
    Creates a shirt with specified size and message, defaulting to large size
    and 'I love Python' message.
    
    Args:
        size (str): The size of the shirt (default: 'large')
        message (str): The message to print on the shirt (default: 'I love Python')
    """
    print(f"Shirt size: {size.title()}, Message: {message}")

# Create a large shirt with default message
make_shirt()

# Create a medium shirt with default message
make_shirt(size="medium")

# Create a shirt of any size (small) with a different message
make_shirt(size="small", message="Code is Life")
# Out:
# Shirt size: Large, Message: I love Python
# Shirt size: Medium, Message: I love Python
# Shirt size: Small, Message: Code is Life

# %%
def make_shirt(size='large', text_message='I love Python'):
    print(f"Shirt size: {size.title()}, Message: {text_message}")

make_shirt()
# Out:
# Shirt size: Large, Message: I love Python

# %%
#8-5 Cities 

def describe_city(city='Galway', country='Ireland'):
    print(f"\n{city.title()} is in {country.title()}.")

describe_city('Reykjavik')
describe_city('Dhaka', 'Bangladesh')
describe_city('Dublin')
describe_city()
# Out:
# Reykjavik is in Ireland.
#
# Dhaka is in Bangladesh.
#
# Dublin is in Ireland.
#
# Galway is in Ireland.

# %% [markdown]
# ## Return Values

# %% [markdown]
# **Returning a Simple Value**

# %%
def get_formatted_name(first_name, last_name):
    full_name = f"{first_name} {last_name}"
    return full_name.title()

musician = get_formatted_name('jimi', 'hendrix')
print(musician)
# Out:
# Jimi Hendrix

# %% [markdown]
# **Making an Argument Optional**

# %%
def get_formatted_name(first_name, middle_name, last_name):
    full_name = f"{first_name} {middle_name} {last_name}"
    return full_name.title()

musician = get_formatted_name('john', 'lee', 'hooker')
print(musician)
# Out:
# John Lee Hooker

# %%
def get_formatted_name(first_name, last_name, middle_name=''):

    if middle_name:
        full_name = f"{first_name} {middle_name} {last_name}"
    else:
        full_name = f"{first_name} {last_name}"
    return full_name.title()

musician = get_formatted_name('jimi', 'hendrix')
print(musician)

musician = get_formatted_name('john', 'hooker', 'lee')
print(musician)
# Out:
# Jimi Hendrix
# John Lee Hooker

# %% [markdown]
# **Returning a Dictionary**

# %%
def build_person(first_name, last_name):
    Person = {'first_name': first_name, 'last': last_name}
    return Person

musician = build_person('jimi', 'hendrix')
print(musician)
# Out:
# {'first_name': 'jimi', 'last': 'hendrix'}

# %%
def build_person(first_name, last_name, age=None):
    person = {'first': first_name, 'last': last_name}
    if age:
        person['age'] = age
    return person

musician = build_person('jimi', 'hendrix', age=27)
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix', 'age': 27}

# %% [markdown]
# **Using a Function with a while Loop**

# %%
def get_formatted_name(first_name, last_name):
    """Return a full name, neatly formatted."""
    full_name = f"{first_name} {last_name}"
    return full_name.title()

 # This is an infinite loop!
while True:
     print("\nPlease tell me your name:")
     print("(enter 'q' at any time to quit)")
     
     f_name = input("First name: ")
     if f_name == 'q':
         break
     l_name = input("Last name: ")
     if l_name == 'q':
         break 
    
     formatted_name = get_formatted_name(f_name, l_name)
     print(f"\nHello, {formatted_name}!")
# Out:
# Please tell me your name:
# (enter 'q' at any time to quit)
# First name:  Fahim
# Last name:  Faisal
# Hello, Fahim Faisal!
#
# Please tell me your name:
# (enter 'q' at any time to quit)
# First name:  q

# %% [markdown]
# ## Exercise

# %%
#8-6 City Names: 

def city_country(city, country):
    city_country = f"{city} {country}"
    return city_country.title()

city = 'Santiago'
country = 'Chile' 
result = city_country(city, country)
print(f'"{city.title()}, {country.title()}"')

city = 'Dhaka'
country = 'Bangladesh'

result = city_country(city, country)
print(f'\n"{city.title()}, {country.title()}"')

city = 'New York'
country = 'USA'

result = city_country(city, country)
print(f'\n"{city.title()}, {country.title()}"')
# Out:
# "Santiago, Chile"
#
# "Dhaka, Bangladesh"
#
# "New York, Usa"

# %%
#8-7 Album 

def make_album(artist, title, songs=None):
    """Create a dictionary representing a music album."""
    album = {
        "artist": artist,
        "title": title
    }
    if songs is not None:
        album["songs"] = songs
    return album

# Create three albums, one with number of songs
album1 = make_album("The Beatles", "Abbey Road")
album2 = make_album("Beyoncé", "Lemonade")
album3 = make_album("Kendrick Lamar", "To Pimp a Butterfly", songs=16)

# Print each album to verify
print(album1)
print(album2)
print(album3)
# Out:
# {'artist': 'The Beatles', 'title': 'Abbey Road'}
# {'artist': 'Beyoncé', 'title': 'Lemonade'}
# {'artist': 'Kendrick Lamar', 'title': 'To Pimp a Butterfly', 'songs': 16}

# %% [markdown]
# ## Passing a List

# %%
def greet_users(names):
    for name in names:
        msg = f"Hello, {name.title()}!"
        print(msg)

usernames = ['Sarah', 'Ty', 'Maggot']
greet_users(usernames)
# Out:
# Hello, Sarah!
# Hello, Ty!
# Hello, Maggot!

# %%
def persons_names(names):
    for name in names:
        msg = f"Hello, {name.title()}"
        print(msg)

usernames = ['Sarah', 'Ty', 'Maggot']
persons_names(usernames)
# Out:
# Hello, Sarah
# Hello, Ty
# Hello, Maggot

# %% [markdown]
# **Modifying a List in a Function**

# %%
# Start with some designs that need to be printed

unprinted_design = ['phone case', 'robot pendant', 'dodcahedron']
completed_models = [] 

# Simulate printing each design, until none are left, 
# Move each design to completed_models after printing. 

while unprinted_design: 
    current_design = unprinted_design.pop()
    print(f"Printing model: {current_design}")
    completed_models.append(current_design)

# Display all completed models. 
print(f"\nThe following models have been printed:")
for completed_model in completed_models:
    print(completed_model)
# Out:
# Printing model: dodcahedron
# Printing model: robot pendant
# Printing model: phone case
#
# The following models have been printed:
# dodcahedron
# robot pendant
# phone case

# %%
def print_models(unprinted_designs, completed_models):
    while unprinted_designs: 
        current_design = unprinted_designs.pop()
        print(f"Printing model: {current_design}")
        completed_models.append(current_design)

def show_completed_models(completed_models):
    """Show all the models that were printed."""
    print("\nThe following models have been printed:")
    for completed_model in completed_models:
        print(completed_model)

unprinted_designs = ['phone case', 'robot pendant', 'dodecahedron']
completed_models = []

print_models(unprinted_designs, completed_models)
show_completed_models(completed_models)
# Out:
# Printing model: dodecahedron
# Printing model: robot pendant
# Printing model: phone case
#
# The following models have been printed:
# dodecahedron
# robot pendant
# phone case

# %% [markdown]
# ## Exercise

# %%
#8-9 Messages: 
def show_message(messages):
    for message in messages:
        msg = f"Fahim, you are {message}!"
        print(msg)

message = ['fired', 'promoted', 'terminated']
show_message(message)
# Out:
# Fahim, you are fired!
# Fahim, you are promoted!
# Fahim, you are terminated!

# %%
#8-10 Sending Messages

def send_messages(new_messages, printed_messages):
    while new_messages: 
        current_message = new_messages.pop()
        print(f"Printing message: {current_message}")
        printed_messages.append(current_message)

def show_printed_messages(printed_messages):
    """Show all the messages that were printed."""
    print("\nThe following messages have been printed:")
    for printed_message in printed_messages:
        print(printed_message)

new_messages = ['fired', 'promoted', 'terminated']
printed_messages= []

send_messages(new_messages, printed_messages)
show_printed_messages(printed_messages)
# Out:
# Printing message: terminated
# Printing message: promoted
# Printing message: fired
#
# The following messages have been printed:
# terminated
# promoted
# fired

# %% [markdown]
# ## Passing an Arbitary Number of Arguments

# %%
def make_pizza(*toppings):
    print("\nMaking a pizza with the following toppings:")
    for topping in toppings:
        print(f"- {topping}")

make_pizza('pepperoni')
make_pizza('mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a pizza with the following toppings:
# - pepperoni
#
# Making a pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %%
def make_pizza(*toppings):
    print("\nMaking a pizza with the following toppings:")
    for topping in toppings:
        print(f"- {topping}")
        
make_pizza('pepperoni')
make_pizza('mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a pizza with the following toppings:
# - pepperoni
#
# Making a pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %%
def make_pizza(size, *toppings):
    print(f"\nMaking a {size}-inch pizza with the following toppings:")
    for topping in toppings:
        print(f"-{topping}")

make_pizza(16, 'pepperoni')
make_pizza(12, 'mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a 16-inch pizza with the following toppings:
# -pepperoni
#
# Making a 12-inch pizza with the following toppings:
# -mushrooms
# -green peppers
# -extra cheese

# %%
def football_players(Name, *Positions):
    print(f"\nTop three players playing with the following attributes:")
    for Position in Positions:
        print(f"-{Name}, {Position}")

football_players('Ronaldo', 'STR')
football_players('Messi', 'STR')
football_players('Mbappe', 'STR')
# Out:
# Top three players playing with the following attributes:
# -Ronaldo, STR
#
# Top three players playing with the following attributes:
# -Messi, STR
#
# Top three players playing with the following attributes:
# -Mbappe, STR

# %% [markdown]
# **Using Arbitary Keyword Arguments**

# %%
def build_profile(first, last, **user_info):
    """Build a dictionary containing everything we know about a user."""
    user_info['first_name'] = first
    user_info['last_name'] = last
    return user_info

user_profile = build_profile('albert', 'einstein',
                             location='princeton',
                             field = 'physics')

print(user_profile)
# Out:
# {'location': 'princeton', 'field': 'physics', 'first_name': 'albert', 'last_name': 'einstein'}

# %% [markdown]
# ## Exercise

# %%
#8-12 Sandwiches 

def sandwiches(*items):
    print(f"\nMaking number of sandwiches:")
    for item in items:
        print(f"-{item}")

sandwiches('chicken sandwich')
sandwiches('cheese sandwich', 'pepperoni sandwich')
sandwiches('beef sandwich', 'pineapple sandwich', 'egg sandwich')
# Out:
# Making number of sandwiches:
# -chicken sandwich
#
# Making number of sandwiches:
# -cheese sandwich
# -pepperoni sandwich
#
# Making number of sandwiches:
# -beef sandwich
# -pineapple sandwich
# -egg sandwich

# %%
#8-13 User Profile 

def build_profile(first, last, **user_info):
    """Build a dictionary containing everything we know about a user."""
    user_info['first_name'] = first
    user_info['last_name'] = last
    return user_info

user_profile = build_profile('albert', 'einstein',
                             location='princeton',
                             field = 'physics')

print(user_profile)
# Out:
# {'location': 'princeton', 'field': 'physics', 'first_name': 'albert', 'last_name': 'einstein'}

# %%
def make_car(manufacturer, model, **kwargs):
    """Build a dictionary containing information about a car."""
    car = {
        'manufacturer': manufacturer,
        'model': model
    }
    car.update(kwargs)  # Incorporate optional keyword arguments
    return car

# Example call with required arguments and two additional name-value pairs
car = make_car('subaru', 'outback', color='blue', tow_package=True)
print(car)
# Out:
# {'manufacturer': 'subaru', 'model': 'outback', 'color': 'blue', 'tow_package': True}

# %%
import pizza

pizza.make_pizza(16, 'pepperoni')
pizza.make_pizza(12, 'mushrooms', 'green peppers', 'extra cheese')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 3
#       1 import pizza
# ----> 3 pizza.make_pizza(16, 'pepperoni')
#       4 pizza.make_pizza(12, 'mushrooms', 'green peppers', 'extra cheese')
#
# AttributeError: module 'pizza' has no attribute 'make_pizza'

# %%
def make_pizza(size, *toppings):
    """Summarize the pizza we are about to make."""
    print(f"\nMaking a {size}-inch pizza with the following toppings:")
    for topping in toppings:
        print(f"- {topping}")

# %%
import pizza

pizza.make_pizza(16, 'pepperoni')
pizza.make_pizza(12, 'mushrooms', 'green peppers', 'extra cheese')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 3
#       1 import pizza
# ----> 3 pizza.make_pizza(16, 'pepperoni')
#       4 pizza.make_pizza(12, 'mushrooms', 'green peppers', 'extra cheese')
#
# AttributeError: module 'pizza' has no attribute 'make_pizza'
