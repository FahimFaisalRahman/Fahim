# %% [markdown]
# # Dictionary

# %% [markdown]
# ## A simple Dictionary

# %%
alien_0 = {
    'color':'green',
    'points': 5
}

print(alien_0['color'])
print(alien_0['points'])
# Out:
# green
# 5

# %% [markdown]
# **Working with Dictionaries**

# %%
alien_0 = {
    'color': 'green',
    'points': 5
}
print(alien_0['color'])
# Out:
# green

# %%
new_points = alien_0['points']

# %%
print(f"You just earned {new_points} points!")
# Out:
# You just earned 5 points!

# %%
alien_O = {
    'color': 'green',
    'points': 5
}
print(alien_O)
# Out:
# {'color': 'green', 'points': 5}

# %%
alien_O['x_position'] = 0
alien_O['y_position'] = 25
print(alien_O)
# Out:
# {'color': 'green', 'points': 5, 'x_position': 0, 'y_position': 25}

# %% [markdown]
# **Starting with an Emtpy Dictionary**

# %%
alien_O = {}

alien_O['color'] = 'green'
alien_O['points'] = 5

print(alien_O)
# Out:
# {'color': 'green', 'points': 5}

# %% [markdown]
# **Modifying Values in a Dictionary**

# %%
alien_O = {'color':'green'}
print(f"The alien is {alien_O['color']}.")

alien_O['color'] = 'yellow'
print(f"The alien is now {alien_O['color']}.")
# Out:
# The alien is green.
# The alien is now yellow.

# %%
alien_o={
    'x_position': 0,
    'y_position': 25,
    'speed': 'fast'
}

print(f"Original position: {alien_o['x_position']}")
# Move the alien to the right
# Determine how far to move the alien based on its current speed. 

if alien_o['speed'] == 'slow':
    x_increament = 1
elif alien_o['speed'] == 'medium':
    x_increament = 2
else:
    #This must be a fast alien 
    x_increament = 3

# The new position is the old position plus the increament. 
alien_o['x_position'] = alien_o['x_position'] + x_increament
print(f"New position: {alien_o['x_position']}")
# Out:
# Original position: 0
# New position: 3

# %% [markdown]
# **Removing Key-Value Pairs**

# %%
alien_o = {
    'color': 'green',
    'points': 5
}
print(alien_o)

del alien_o['points']
print(alien_o)
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'green'}

# %% [markdown]
# **A dictionary of Similar Objects**

# %%
favorite_languages = {
    'Jen' : 'Python', 
    'Sarah': 'C', 
    'Edward': 'Rust',
    'Phil': 'Python',
}
print(favorite_languages)
# Out:
# {'Jen': 'Python', 'Sarah': 'C', 'Edward': 'Rust', 'Phil': 'Python'}

# %%
language = favorite_languages['Sarah'].title()
print(f"Sarah's favorite language is {language}.")
# Out:
# Sarah's favorite language is C.

# %%
favorite_languages['Sarah']
# Out:
# 'C'

# %%
favorite_languages['Jen']
# Out:
# 'Python'

# %%
alien_o = {
    'color': 'green',
    'speed': 'slow'
}

print(alien_o['points'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 6
#       1 alien_o = {
#       2     'color': 'green',
#       3     'speed': 'slow'
#       4 }
# ----> 6 print(alien_o['points'])
#
# KeyError: 'points'

# %%
print_value = alien_o.get('points', 'No point value assigned.')
print(print_value)
# Out:
# No point value assigned.

# %% [markdown]
# **Exercise**

# %%
#6-1 Person: 

Person = {
    'First Name': 'Fahim', 
    'Last Name': 'Faisal',
    'Age': 20,
    'City': 'Dhaka'
}

print(Person)

#6-2 Favorite_number

favorite_number = {
    'Fahim': 1,
    'Faisal': 2,
    'Rahman': 3,
    'Kaniz': 4,
    'Mafiz': 5,
    'Badhon': 6,
    'Zareen': 7
        }
print(favorite_number)


#6-3 Glossary 

glossary = {
    'List': 'Ordered collection',
    'Function': 'Reusable code',
    'Loop': 'Repeated execution',
    'Module': 'Code library'
}
print(glossary)
# Out:
# {'First Name': 'Fahim', 'Last Name': 'Faisal', 'Age': 20, 'City': 'Dhaka'}
# {'Fahim': 1, 'Faisal': 2, 'Rahman': 3, 'Kaniz': 4, 'Mafiz': 5, 'Badhon': 6, 'Zareen': 7}
# {'List': 'Ordered collection', 'Function': 'Reusable code', 'Loop': 'Repeated execution', 'Module': 'Code library'}

# %% [markdown]
# ## Looping Through a Dictionary

# %% [markdown]
# **Looping Through All Key-Value Pairs**

# %%
user_o = {
    'username': 'efermi',
    'first': 'enrico',
    'last': 'fermi',
}

# %%
for key, value in user_o.items():
    print(f"\nKey: {key}")
    print(f"\nValue: {value}")
# Out:
# Key: username
#
# Value: efermi
#
# Key: first
#
# Value: enrico
#
# Key: last
#
# Value: fermi

# %%
favorite_languages = {
    'Jen': 'Python', 
    'Sarah': 'C',
    'Edward': 'Rust',
    'Phil': 'Python',
}

for name, language in favorite_languages.items():
    print(f"{name.title()}'s favorite language is {language.title()}.")
# Out:
# Jen's favorite language is Python.
# Sarah's favorite language is C.
# Edward's favorite language is Rust.
# Phil's favorite language is Python.

# %%
for name in favorite_languages.keys():
    print(name.title())
# Out:
# Jen
# Sarah
# Edward
# Phil

# %%
favorite_languages = {
    'Jen': 'Python', 
    'Sarah': 'C',
    'Edward': 'Rust',
    'Phil': 'Python',
}
friends = ['Sarah', 'Phil']
for name in favorite_languages.keys():
    print(f"Hi {name.title()}.")
    
    if name in friends:
        language = favorite_languages[name].title()
        print(f"\t{name.title()}, I see you love {language}!")
# Out:
# Hi Jen.
# Hi Sarah.
# 	Sarah, I see you love C!
# Hi Edward.
# Hi Phil.
# 	Phil, I see you love Python!

# %%
if 'erin' not in favorite_languages.keys():
    print("Erin, please take our poll!")
# Out:
# Erin, please take our poll!

# %% [markdown]
# **Looping Through a Dictionary's Keys in a Particular Order**

# %%
favorite_languages = {
    'Jen': 'Python', 
    'Sarah': 'C',
    'Edward': 'Rust',
    'Phil': 'Python',
}
for name in sorted(favorite_languages.keys()):
    print(f"{name.title()}, thank you for taking the poll.")
# Out:
# Edward, thank you for taking the poll.
# Jen, thank you for taking the poll.
# Phil, thank you for taking the poll.
# Sarah, thank you for taking the poll.

# %% [markdown]
# **Looping Through All Values in a Dictionary**

# %%
print("The following languages have been mentioned:")
for language in favorite_languages.values():
    print(language.title())
# Out:
# The following languages have been mentioned:
# Python
# C
# Rust
# Python

# %%
print("The following languages have been mentioned:")
for language in set(favorite_languages.values()):
    print(language.title())
# Out:
# The following languages have been mentioned:
# Rust
# C
# Python

# %%
languages = {'python', 'rust', 'c'}
languages
# Out:
# {'c', 'python', 'rust'}

# %% [markdown]
# **Exercise**

# %%
# 6-4 Glossary 2 


glossaries = {
    'List': 'Ordered collection',
    'Function': 'Reusable code',
    'Loop': 'Repeated execution',
    'Module': 'Code library'
}

for key, value in glossaries.items():
    print(f"\nKey: {key}")
    print(f"\nValue: {value}")


# 6-5 Rivers

Rivers = {
    'Yellow':'China',
    'Nile ':'Egypt',
    'Amazon ':'Brazil',
}

for river, country in Rivers.items():
    print(f"\nThe river {river.title()} runs through {country.title()}.")
# Out:
# Key: List
#
# Value: Ordered collection
#
# Key: Function
#
# Value: Reusable code
#
# Key: Loop
#
# Value: Repeated execution
#
# Key: Module
#
# Value: Code library
#
# The river Yellow runs through China.
#
# The river Nile  runs through Egypt.
#
# The river Amazon  runs through Brazil.

# %%
for river in Rivers.keys():
    print(f"Rivers: {river.title()}.")
# Out:
# Rivers: Yellow River.
# Rivers: Nile .
# Rivers: Amazon .

# %%
for country in Rivers.values():
    print(f"Country: {country.title()}.")
# Out:
# Country: China.
# Country: Egypt.
# Country: Brazil.

# %% [markdown]
# ## Nesting

# %% [markdown]
# **A list of Dictionary**

# %%
alien_0 = {
    'color': 'green',
    'points': 5}
alien_1 = {
    'color':'yellow',
    'points': 10}
alien_2 = {
    'color': 'red',
    'points': 15}

aliens = [alien_0, alien_1, alien_2]

for alien in aliens:
    print(alien)
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'yellow', 'points': 10}
# {'color': 'red', 'points': 15}

# %%
# Make an empty list for storing aliens. 

aliens = []

# Make 30 green aliens. 
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

# Show the first 5 aliens.
for alien in aliens[:5]:
    print(alien)
print("...")

#Show how many have been created. 
print(f"Total number of aliens: {len(aliens)}")
# Out:
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# Total number of aliens: 30

# %%
# Make an empty list for storing aliens. 

aliens = []

# Make 30 green aliens. 
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

for alien in aliens[:3]:
    if alien ['color']== 'green':
        alien['color'] = 'yellow'
        alien['speed'] = 'medium'
        alien['points'] = 10
    elif alien['color'] == 'yellow':
        alien['color'] = 'red'
        alien['speed'] = 'fast'
        alien['points'] = 15

# Show the first 5 aliens.
for alien in aliens[:5]:
    print(alien)
print("...")

#Show how many have been created. 
print(f"Total number of aliens: {len(aliens)}")
# Out:
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# ...
# Total number of aliens: 30

# %% [markdown]
# **A list in a Dictionary**

# %%
# Store information about a pizza being ordered

pizza = {
    'crust': 'thick',
    'toppings': ['mushrooms', 'extra cheese'],
}

# Summarize the order 
print(f"You ordered a {pizza['crust']}-crust pizza "
      "with the following toppings:")

for topping in pizza['toppings']:
    print(f"\t{topping}")
# Out:
# You ordered a thick-crust pizza with the following toppings:
# 	mushrooms
# 	extra cheese

# %%
favorite_languages = {
    'jen': ['python', 'rust'],
    'sarah': ['c'],
    'edward': ['rust', 'go'],
    'phil': ['python', 'haskell'],
}

for name, languages in favorite_languages.items():
    print(f"\n{name.title()}'s favorite_languages are:")
    for language in languages:
        print(f"\t{language.title()}")
# Out:
# Jen's favorite_languages are:
# 	Python
# 	Rust
#
# Sarah's favorite_languages are:
# 	C
#
# Edward's favorite_languages are:
# 	Rust
# 	Go
#
# Phil's favorite_languages are:
# 	Python
# 	Haskell

# %% [markdown]
# **A Dictionary in a Dictionary**

# %%
users = {
    'aeinstein': {
        'first': 'albert',
        'last': 'einstein',
        'location': 'princeton',
    },


    'mcurie': {
        'first': 'marie',
        'last': 'curie',
        'location': 'paris',
    },
}

for username, user_info in users.items():
    print(f"\nUsername: {username}")
    full_name = f"{user_info['first']} {user_info['last']}"
    location = user_info['location']

    print(f"\tFill_name: {full_name.title()}")
    print(f"\tLocation: {location.title()}")
# Out:
# Username: aeinstein
# 	Fill_name: Albert Einstein
# 	Location: Princeton
#
# Username: mcurie
# 	Fill_name: Marie Curie
# 	Location: Paris

# %%
# 6-7 People: 

Person = {
    'First Name': 'Fahim', 
    'Last Name': 'Faisal',
    'Age': 20,
    'City': 'Dhaka'
}

Person_2 = {
    'First Name': 'Jack', 
    'Last Name': 'Greelish',
    'Age': 20,
    'City': 'London'
}

Person_3 = {
     'First Name': 'Eden', 
    'Last Name': 'Hazard',
    'Age': 20,
    'City': 'Chelsea'
}

Peoples = [Person, Person_2, Person_3]


for People in Peoples:
    print(People)
# Out:
# {'First Name': 'Fahim', 'Last Name': 'Faisal', 'Age': 20, 'City': 'Dhaka'}
# {'First Name': 'Jack', 'Last Name': 'Greelish', 'Age': 20, 'City': 'London'}
# {'First Name': 'Eden', 'Last Name': 'Hazard', 'Age': 20, 'City': 'Chelsea'}

# %%
# 6-9 Favorite_Places 


favorite_places = {
    'jen': ['London', 'Adelaide'],
    'smith': ['Brisbaine', 'Melbourne'],
    'fahim': ['NewYork', 'California'],
}

for name, location in favorite_places.items():
    print(f"\n{name.title()}'s favorite places are:")
    for location in location:
        print(f"\t{location.title()}")
# Out:
# Jen's favorite places are:
# 	London
# 	Adelaide
#
# Smith's favorite places are:
# 	Brisbaine
# 	Melbourne
#
# Fahim's favorite places are:
# 	Newyork
# 	California

# %%
Cities = {
    'Dhaka': {
        'Country': 'Bangladesh',
        'Population': '10M',
        'Fact': 'Shaheed Minar',
    },


    'New York': {
        'Country': 'USA',
        'Population': '20M',
        'Fact': 'Twin Tower',
    },

    'London': {
        'Country': 'UK',
        'Population': '30M',
        'Fact': 'London Tower',
    
},
}

for city, city_info in Cities.items():
    print(f"\nCity: {city}")
    Country = f"{city_info['Country']}"
    Population = city_info['Population']
    Fact = city_info['Fact']

    print(f"\tCountry: {Country.title()}")
    print(f"\tPopulation: {Population.title()}")
    print(f"\tFact: {Fact.title()}")
# Out:
# City: Dhaka
# 	Country: Bangladesh
# 	Population: 10M
# 	Fact: Shaheed Minar
#
# City: New York
# 	Country: Usa
# 	Population: 20M
# 	Fact: Twin Tower
#
# City: London
# 	Country: Uk
# 	Population: 30M
# 	Fact: London Tower
