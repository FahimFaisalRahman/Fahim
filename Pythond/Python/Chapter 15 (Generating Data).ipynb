# %% [markdown]
# # Generating Data

# %% [markdown]
# ## Ploting Simple Line Graph

# %%
import matplotlib.pyplot as plt 
squares = [1, 4, 9, 16, 25]
fig, ax = plt.subplots()
ax.plot(squares)
plt.show()

# %% [markdown]
# ## Changing the label Type and Line Thickness

# %%
import matplotlib.pyplot as plt
squares = [1,4,9,16,25]
fig, ax = plt.subplots()
ax.plot(squares, linewidth=3)

# Set chart title and label axes 
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)
# Set size of tick labels
ax.tick_params(labelsize=14)
plt.show()

# %% [markdown]
# ## Correcting the plot

# %%
import matplotlib.pyplot as plt 
input_values = [1, 2, 3, 4, 5]
squares = [1, 4, 9, 16, 25]

fig,ax = plt.subplots()
ax.plot(input_values, squares, linewidth=3)

# Set chart title and label axes 
ax.set_title("Square Numbers")
ax.set_xlabel("Value")
ax.set_ylabel("Square of values")

ax.tick_params(labelsize=14)
plt.show()

# %% [markdown]
# ## Using Built-in Styles

# %%
import matplotlib.pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt

input_values = [1, 2, 3, 4, 5]
square_values = [1, 4, 9, 16, 25]

plt.style.use('seaborn-v0_8-white')
fig, ax = plt.subplots()
ax.plot(input_values, squares, linewidth=3)

ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Values", fontsize=14)
ax.set_ylabel("Square of Values", fontsize=14)

ax.tick_params(labelsize=14)
plt.show()

# %% [markdown]
# ## Plotting and Styling Individual Points with scatter()

# %%
import matplotlib.pyplot as plt 
square_numbers = [1, 4, 9, 16, 25]
input_values = [1, 2, 3, 4, 5]
plt.style.use('seaborn-v0_8-white')
fig,ax = plt.subplots()
ax.scatter(2, 4)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-darkgrid')
fig, ax = plt.subplots()
ax.scatter(2, 4, s=200)

# Set chart title and label axes 
ax.set_title("Square Numbers", fontsize=24)
ax.set_xlabel("Value", fontsize=14)
ax.set_ylabel("Square of Value", fontsize=14)

# Set size of tick labels 
ax.tick_params(labelsize=14)
plt.show()

# %% [markdown]
# ## Plotting a Series of Points with scatter()

# %%
import matplotlib.pyplot as plt
x_values = [1, 2, 3, 4, 5]
y_values = [1, 4, 9, 16,  25]

plt.style.use('seaborn-v0_8-white')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=100)

ax.set_title('Square Numbers')
ax.set_xlabel('Value')
ax.set_ylabel('Square of Value')

ax.tick_params(labelsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
input_values = [1, 2, 3, 4, 5]
output_values = [1, 4, 9, 16, 25]

plt.style.use('seaborn-v0_8-white')
fig, ax = plt.subplots()
ax.plot(input_values, output_values, linewidth=3)

ax.set_title('Square Numbers')
ax.set_xlabel('Value', fontsize=14)
ax.set_ylabel('Square of Value', fontsize=14)

ax.tick_params(labelsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt 
x = [1, 2, 3, 4, 5]
y= [1, 4, 9, 16, 25]

plt.style.use('seaborn-v0_8-white')
fig, ax = plt.subplots()
ax.scatter(x, y, s=100)

ax.set_title('Square Numbers', fontsize=24)
ax.set_xlabel('Value',fontsize=14)
ax.set_ylabel('Square of Value', fontsize=14)

ax.tick_params(labelsize=14)
plt.show()

# %% [markdown]
# ## Calculating Data Automatically

# %%
import matplotlib.pyplot as plt 
x_values = range(1, 1001)
y_values = [x**2 for x in x_values] 

plt.style.use('seaborn-v0_8-white')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=10)

ax.set_title('Square Numbers', fontsize=24)
ax.set_xlabel('Value', fontsize=14)
ax.set_ylabel('Square of Values', fontsize=14)

# Set the range for each axis 
ax.axis([0, 1100, 0, 1_100_000])
plt.show()

# %% [markdown]
# ## Customizing Tick Labels

# %%
import matplotlib.pyplot as plt
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn-v0_8-white')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, s=10)

ax.set_title('Square Numbers', fontsize=24)
ax.set_xlabel('Value', fontsize=14)
ax.set_ylabel('Square of Values', fontsize=14)

ax.axis([0, 1100, 0, 1_000_000])
ax.ticklabel_format(style='plain')
plt.show()

# %% [markdown]
# ## Defining Custom Colors

# %%
import matplotlib.pyplot as plt
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn-v0_8-white')
fig, ax = plt.subplots()
# ax.scatter(x_values, y_values, color='red', s=10)
# ax.scatter(x_values, y_values, color=(0, 0.8, 0), s=10)
# Using a Colormap 
ax.scatter(x_values, y_values, c=y_values, cmap=plt.cm.Blues, s=10)

ax.set_title('Square Numbers', fontsize=24)
ax.set_xlabel('Value', fontsize=14)
ax.set_ylabel('Square of Values', fontsize=14)

ax.axis([0, 1100, 0, 1_000_000])
plt.show()

# %%
import matplotlib.pyplot as plt
x_values = range(1, 1001)
y_value = [x**2 for x in x_values]

plt.style.use('seaborn-v0_8-white')
fig, ax = plt.subplots()
ax.scatter(x_values, y_values, color=(0, 0.8, 0), s=10)

ax.set_title('Square Numbers', fontsize=24)
ax.set_xlabel('Values', fontsize=14)
ax.set_ylabel('Square of Values', fontsize=14)

ax.axis([0, 1100, 0, 1_000_000])
plt.show()
plt.savefig('square_plot.png', bbox_inches='tight')

# %% [markdown]
# ## Exercise

# %%
import matplotlib.pyplot as plt

# Data for the first five cubic numbers
n = [1, 2, 3, 4, 5]
cubes = [x**3 for x in n]  # [1, 8, 27, 64, 125]

# Create the plot
fig, ax = plt.subplots()
ax.plot(n, cubes, marker='o', linestyle='-', color='b', label='n³')

# Set labels and title
ax.set_xlabel('n')
ax.set_ylabel('n³')
ax.set_title('First Five Cubic Numbers')
ax.legend()

# Set x-axis ticks to integers
ax.set_xticks(n)

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ## Random Walks

# %% [markdown]
# **Creating the RandomWalks Class**

# %%
import random
from random import choice

class RandomWalk:
    """A class to generate random walks."""

    def __init__(self, num_points=500):
        self.num_points = num_points 

        # All walks start at (0,0). 
        self.x_values = [0]
        self.y_values = [0]

# %% [markdown]
# **Choosing Directions**

# %%
def fill_walk(self):
    """Calculate all the points in the walk."""
    # Keep taking steps until the walk reaches the desired length. 
    while len(self.x_values) < self.num_points:
        # Decide which direction to go, and how far to go. 
        x_direction = choice([1, -1])
        x_distance = choice([0, 1, 2, 3, 4])
        x_step = x_direction * x_distance 

        y_direction = choice([1, -1])
        y_distance = choice([0,1,2,3,4])
        y_step = y_direction * y_distance 

        # Reject moves that go nowwhere. 
        if x_step == 0 and y_step ==0:
            continue

        # Calculate the new position. 
        x = self.x_values[-1] + x_step
        y = self.y_values[-1] + y_step 

        self.x_values.append(x)
        self.y_values.append(y)

# %% [markdown]
# **Plotting the Random Walk**

# %%
# !pip install random_walk
# Out:
# ERROR: Could not find a version that satisfies the requirement random_walk (from versions: none)
# ERROR: No matching distribution found for random_walk

# %%
import matplotlib.pyplot as plt 
from random_walk import RandomWalk 

# Make a random walk 
rw = RandomWalk()
rw.fill_walk()

# Plot the points in the walk 
plt.style.use('classic')
fig, ax = plt.subplots()

ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 from random_walk import RandomWalk
#       4 # Make a random walk
#       5 rw = RandomWalk()
#
# ModuleNotFoundError: No module named 'random_walk'

# %%
import random

class RandomWalk:
    """A class to generate random walks."""
    
    def __init__(self, num_points=5000):
        """Initialize attributes of a walk."""
        self.num_points = num_points
        # All walks start at (0, 0)
        self.x_values = [0]
        self.y_values = [0]
    
    def fill_walk(self):
        """Calculate all the points in the walk."""
        while len(self.x_values) < self.num_points:
            # Decide direction and distance to move
            x_direction = random.choice([1, -1])  # Move right (+1) or left (-1)
            x_distance = random.choice([0, 1, 2, 3, 4])  # Step size
            x_step = x_direction * x_distance
            
            y_direction = random.choice([1, -1])  # Move up (+1) or down (-1)
            y_distance = random.choice([0, 1, 2, 3, 4])  # Step size
            y_step = y_direction * y_distance
            
            # Reject moves that go nowhere
            if x_step == 0 and y_step == 0:
                continue
            
            # Calculate the new position
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step
            
            self.x_values.append(x)
            self.y_values.append(y)

# Make a random walk
rw = RandomWalk()
rw.fill_walk()

# Plot the points in the walk
plt.style.use('classic')
fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
from random_walk import RandomWalk

# Make a random walk
rw = RandomWalk()
rw.fill_walk()

# Plot the points in the walk
plt.style.use('classic')
fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[50], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 from random_walk import RandomWalk
#       4 # Make a random walk
#       5 rw = RandomWalk()
#
# ModuleNotFoundError: No module named 'random_walk'

# %%
import matplotlib.pyplot as plt
import random

# Define the RandomWalk class
class RandomWalk:
    """A class to generate random walks."""
    
    def __init__(self, num_points=5000):
        """Initialize attributes of a walk."""
        self.num_points = num_points
        self.x_values = [0]
        self.y_values = [0]
    
    def fill_walk(self):
        """Calculate all the points in the walk."""
        while len(self.x_values) < self.num_points:
            x_direction = random.choice([1, -1])
            x_distance = random.choice([0, 1, 2, 3, 4])
            x_step = x_direction * x_distance
            
            y_direction = random.choice([1, -1])
            y_distance = random.choice([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance
            
            if x_step == 0 and y_step == 0:
                continue
            
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step
            
            self.x_values.append(x)
            self.y_values.append(y)

# Make a random walk
rw = RandomWalk()
rw.fill_walk()

# Plot the points in the walk
plt.style.use('classic')
fig, ax = plt.subplots()
ax.scatter(rw.x_values, rw.y_values, s=15)
ax.set_aspect('equal')
plt.show()
