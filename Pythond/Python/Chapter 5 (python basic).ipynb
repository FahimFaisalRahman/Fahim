# %% [markdown]
# # Chapter 5: IF Statement

# %%
cars = ['audi', 'bmw', 'subaru', 'toyota']
for car in cars:
    if car == 'bmw':
        print(car.upper())
    else:
        print(car.title())
# Out:
# Audi
# BMW
# Subaru
# Toyota

# %% [markdown]
# **Checking for Inequality**

# %%
requested_toppings = 'mushroom' 

if requested_toppings !='anchovies':
    print("Hold the anchovies!")
# Out:
# Hold the anchovies!

# %%
car = 'Audi'
car.lower() == 'audi'
# Out:
# True

# %%
answer = 17

if answer!=42:
    print("That is not the correct answer. Please try again!")
# Out:
# That is not the correct answer. Please try again!

# %%
requested_toppings = ['mushrooms', 'onions', 'pineapple']
'mushrooms' in requested_toppings
# Out:
# True

# %%
'pepproni' in requested_toppings
# Out:
# False

# %%
banned_users = ['andrew', 'carolina', 'david']

user = 'marie'

if user not in banned_users: 
    print(f"{user.title()}, you can post a response if you wish.")
# Out:
# Marie, you can post a response if you wish.

# %% [markdown]
# **if Statements**

# %%
age = 19 
if age >=18:
    print("You are old enough to vote!")
# Out:
# You are old enough to vote!

# %% [markdown]
# **if-else Statements**

# %%
age = 17
if age >=18:
    print("You are old enough to vote!")
    print("Have you registered to vote yet?")
else:
    print("Sorry, you are too young to vote.")
    print("Please register to vote as soon as you turn 18!")
# Out:
# Sorry, you are too young to vote.
# Please register to vote as soon as you turn 18!

# %% [markdown]
# **if-elif-else chain**

# %%
age =12 
if age < 4: 
    print("Your admission cost is $0.")
elif age <18:
    print("Your admission cost is $25.")
else: 
    print("Your admission cost is $40.")
# Out:
# Your admission cost is $25.

# %%
age = 12
if age<4:
    price = 0
elif age<18:
    price = 25
else:
    price = 40 

print(f"Your admission cost is ${price}.")
# Out:
# Your admission cost is $25.

# %% [markdown]
# **Using Multiple elif Block**

# %%
age = 1
if age<4:
    price = 0
elif age<18:
    price = 25
elif age<65:
    price = 40
else:
    price = 20

print(f"Your admission cost is ${price}.")
# Out:
# Your admission cost is $0.

# %% [markdown]
# **Omiting else block**

# %%
age = 12
if age < 4:
    price = 0 
elif age < 18: 
    price = 25
elif age <65:
    price = 40
elif age>65:
    price = 20 

print(f"Your admission cost is ${price}.")
# Out:
# Your admission cost is $25.

# %% [markdown]
# **Testing Multiple Conditions**

# %%
requested_toppings = ['mushrooms', 'extra cheese']

if 'mushrooms' in requested_toppings:
    print("Adding mushrooms.")
if 'pepperoni' in requested_toppings:
    print("Adding pepperoni.")
if 'extra cheese' in requested_toppings:
    print("Adding extra cheese.")

print("\nFinished making your pizza.")
# Out:
# Adding mushrooms.
# Adding extra cheese.
#
# Finished making your pizza.

# %%
# 5-3 Alien Colors #1

alien_color = ['green', 'yellow', 'red']

if 'green' in alien_color:
    print("You have just earned 5 points")
# Out:
# You have just earned 5 points

# %%
if 'yellow' in alien_color:
    print("You have just earned 10 points.")
if 'maroon' in alien_color:
    print("You have just earned infinity points.")
# Out:
# You have just earned 10 points.

# %%
#5-4 Alien colors # 2

if 'green' in alien_color:
    print("You have just earned 5 points.")
if alien_color!='maroon':
    print("You have just earned 10 points.")
# Out:
# You have just earned 5 points.
# You have just earned 10 points.

# %%
if alien_color =='yellow':
    print("You have just earned 5 points.")
else:
    print("You have just earned 10 points.")
# Out:
# You have just earned 10 points.

# %%
#5-5 Alien Colors 
alien_color = 'red'

if alien_color == 'green':
    print("You have just earned 5 points.")
elif alien_color == 'yellow':
    print("You have just earned 10 points.")
elif alien_color == 'red':
    print("You have just earned 15 points.")
else:
    print("You have just earned infinite point.")
# Out:
# You have just earned 15 points.

# %%
#5-6 
age = 50
if age <2:
    print("You are a baby.")
elif age<4:
    print("You are a toddler.")
elif age<13:
    print("You are a kid.")
elif age<20:
    print("You are a teenager.")
elif age<65:
    print("You are an adult.")
else:
    print("You are an elder.")
# Out:
# You are an adult.

# %%
favorite_foods = ['bananas', 'mango', 'pinapple', 'apple', 'orange']

if 'bananas' in favorite_foods:
    print("You really likes bananas.")
if 'jackfruit' in favorite_foods:
    print("You really like jackfruits.")
if 'watermelon' in favorite_foods:
    print("You really like watermelon.")
if 'mango' in favorite_foods:
    print("You really like mango.")
if 'orange' in favorite_foods:
    print("You really like orange.")
# Out:
# You really likes bananas.
# You really like mango.
# You really like orange.

# %% [markdown]
# **Using if Statements with Lists**

# %% [markdown]
# *Checking for Speical Items*

# %%
requested_toppings = ['mushrooms', 'green peppers', 'extra cheese']

for requested_topping in requested_toppings:
    print(f"Adding {requested_topping}.")

print("\nFinished making your pizza.")
# Out:
# Adding mushrooms.
# Adding green peppers.
# Adding extra cheese.
#
# Finished making your pizza.

# %%
requested_toppings = ['mushrooms', 'green peppers', 'extra cheese']

for requested_topping in requested_toppings:
    if requested_topping == 'green peppers':
        print("Sorry, we are out of green pepper.")
    else:
        print(f"Adding {requested_topping}.")

print("\nFinished making your pizza.")
# Out:
# Adding mushrooms.
# Sorry, we are out of green pepper.
# Adding extra cheese.
#
# Finished making your pizza.

# %%
requested_toppings = [] 

if requested_toppings:
    for requested_topping in requested_toppings:
        print(f"Adding {requested_toppings}.")
    print("\nFinished making your pizza!")
else:
    print("Are you sure you want plain pizza?")
# Out:
# Are you sure you want plain pizza?

# %% [markdown]
# **Using Multiple Lists**

# %%
available_toppings = ['mushrooms', 'olives', 'green peppers', 
                      'pepperoni', 'pineapple', 'extra cheese']

requested_toppings = ['mushrooms', 'french fries', 'extra cheese'] 

for requested_topping in requested_toppings:
    if requested_topping in available_toppings:
        print(f"Adding {requested_topping}.")
    else:
        print(f"Sorry, we don't have {requested_topping}.")

print("\nFinished making your pizza!")
# Out:
# Adding mushrooms.
# Sorry, we don't have french fries.
# Adding extra cheese.
#
# Finished making your pizza!

# %%
#5-8

usernames = ['Fahim', 'Faisal', 'admin' , 'Jack', 'Tom']

for username in usernames:
    print(f"Hello {username.title()}, would you like to see a status report?")
# Out:
# Hello Fahim, would you like to see a status report?
# Hello Faisal, would you like to see a status report?
# Hello Admin, would you like to see a status report?
# Hello Jack, would you like to see a status report?
# Hello Tom, would you like to see a status report?

# %%
# Define a list of usernames, including 'admin'
usernames = ['admin', 'jaden', 'sarah', 'mike', 'emma', 'john']

# Loop through the list of usernames
for username in usernames:
    # Check if the username is 'admin'
    if username == 'admin':
        print("Hello admin, would you like to see a status report?")
    else:
        # Capitalize the first letter of the username for the generic greeting
        print(f"Hello {username.capitalize()}, thank you for logging in again.")
# Out:
# Hello admin, would you like to see a status report?
# Hello Jaden, thank you for logging in again.
# Hello Sarah, thank you for logging in again.
# Hello Mike, thank you for logging in again.
# Hello Emma, thank you for logging in again.
# Hello John, thank you for logging in again.
